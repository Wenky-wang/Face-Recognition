# %% [markdown]
# ## CSIS 4260 - Facial Recognition - Family Camera

# %%
import face_recognition
import os, sys
import cv2
import numpy as np
import math

# %%
## variables adjustment
video_selection = 1
lowest_confidence = 95

# %%
# Algorithm to convert face_distance to confidence
def face_confidence(face_distance, face_match_threshold=0.6):
    range = (1.0 - face_match_threshold)
    linear_val = (1.0 - face_distance) / (range * 2.0)

    if face_distance > face_match_threshold:
        return str(round(linear_val * 100, 2)) + '%'
    else:
        value = (linear_val + ((1.0 - linear_val) * math.pow((linear_val - 0.5) * 2, 0.2))) * 100
        return str(round(value, 2)) + '%'


class FaceRecognition:
    face_locations = []
    face_encodings = []
    face_names = []
    known_face_encodings = []
    known_face_names = []
    process_current_frame = True

    def __init__(self):
        self.encode_faces()

    def encode_faces(self):
        for image in os.listdir('faces_gr_tiny'):
            print(image)
            face_image = face_recognition.load_image_file(f"faces_gr_tiny/{image}")
            face_encoding = face_recognition.face_encodings(face_image)[0]

            self.known_face_encodings.append(face_encoding)
            self.known_face_names.append(image)

        print(len(self.known_face_names))

    def run_recognition(self, video_select, lowest):
        video_capture = cv2.VideoCapture(video_select)

        if not video_capture.isOpened():
            sys.exit('## ERROR: Video source not found')

        while True:
            ret, frame = video_capture.read()

            # Only process every other frame of video to save time
            if self.process_current_frame and ret:
                    
                #########
                # Resize frame of video to 1/4 size for faster face recognition processing
                small_frame = cv2.resize(frame, (0, 0), fx=0.25, fy=0.25)

                # Convert the image from BGR color (which OpenCV uses) to RGB color (which face_recognition uses)
                rgb_small_frame = small_frame[:, :, ::-1]

                # Find all the faces and face encodings in the current frame of video
                self.face_locations = face_recognition.face_locations(rgb_small_frame)
                self.face_encodings = face_recognition.face_encodings(rgb_small_frame, self.face_locations)

                self.face_names = []
                for face_encoding in self.face_encodings:
                    
                     # 1) See if the face is a match for the known face(s)
#                     matches = face_recognition.compare_faces(self.known_face_encodings, face_encoding)
                    name = "Unknown"
                    confidence = ""

                    # 2) Calculate the shortest distance to face (what method?)
                    face_distances = face_recognition.face_distance(self.known_face_encodings, face_encoding)

                    best_match_index = np.argmin(face_distances)
                    if 0 <= best_match_index and best_match_index < len(self.known_face_names):
                        confidence_est = face_confidence(face_distances[best_match_index])
                        confidence_num = float(confidence_est[:-1])
                        if confidence_num >= lowest:
                            name = self.known_face_names[best_match_index][:-7]
                            confidence = '('+confidence_est+')'

                    self.face_names.append(f'{name} {confidence}')

            self.process_current_frame = not self.process_current_frame

            # Display the results
            for (top, right, bottom, left), name in zip(self.face_locations, self.face_names):
                # Scale back up face locations since the frame we detected in was scaled to 1/4 size
                top *= 4
                right *= 4
                bottom *= 4
                left *= 4

                # Create the frame with the name
                if confidence_num >= lowest:
                    cv2.rectangle(frame, (left, top), (right, bottom), (0, 128, 255), 2)
                    cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (0, 128, 255), cv2.FILLED)
                else:
                    cv2.rectangle(frame, (left, top), (right, bottom), (255, 102, 102), 2)
                    cv2.rectangle(frame, (left, bottom - 35), (right, bottom), (255, 102, 102), cv2.FILLED)
                cv2.putText(frame, name, (left + 6, bottom - 6), cv2.FONT_HERSHEY_DUPLEX, 0.8, (255, 255, 255), 2)

            # Display the resulting image
            cv2.imshow('Face Recognition', frame)

            # Hit 'q' on the keyboard to quit!
            if cv2.waitKey(1) == ord('q'):
                break

        # Release handle to the webcam
        video_capture.release()
        cv2.destroyAllWindows()

# %%
## execution
if __name__ == '__main__':
    fr = FaceRecognition()
    fr.run_recognition(video_select=video_selection, lowest=lowest_confidence)
# Out:
# Unknown_22.png
# Arun_01.png
# Unknown_23.png
# Unknown_09.png
# Arun_03.png
# Unknown_21.png
# Unknown_20.png
# Unknown_08.png
# Arun_06.png
# Arun_12.png
# Unknown_24.png
# Unknown_18.png
# Unknown_19.png
# Unknown_25.png
# Arun_13.png
# Arun_11.png
# Unknown_27.png
# Arun_05.png
# Arun_04.png
# Unknown_26.png
# Ozzy_06.png
# Ozzy_12.png
# Ozzy_13.png
# Ozzy_07.png
# Ozzy_11.png
# Ozzy_05.png
# Ozzy_04.png
# William_08.png
# William_09.png
# Ozzy_03.png
# Sid_09.png
# Wenky_08.png
# Wenky_09.png
# Sid_08.png
# Ozzy_02.png
# Sid_05.png
# Sid_11.png
# Wenky_04.png
# Wenky_10.png
# William_07.png
# William_13.png
# William_12.png
# William_06.png
# Wenky_11.png
# Wenky_05.png
# Sid_10.png
# Sid_12.png
# Sid_06.png
# Wenky_13.png
# Wenky_07.png
# William_10.png
# William_04.png
# William_05.png
# William_11.png
# Wenky_06.png
# Wenky_12.png
# Sid_07.png
# Sid_13.png
# Sid_03.png
# Ozzy_09.png
# Wenky_02.png
# William_01.png
# Wenky_03.png
# Ozzy_08.png
# Sid_16.png
# Sid_14.png
# Wenky_01.png
# William_03.png
# Wenky_14.png
# Sid_15.png
# Arun_09.png
# Unknown_03.png
# Unknown_17.png
# Unknown_16.png
# Unknown_02.png
# Unknown_28.png
# Unknown_14.png
# Unknown_01.png
# Unknown_15.png
# Unknown_11.png
# Unknown_05.png
# Unknown_04.png
# Unknown_10.png
# Unknown_06.png
# Unknown_12.png
# Unknown_13.png
# Unknown_07.png
# 87
# 1   HIToolbox                           0x00007ff813c42726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff813c422b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff813bb1cd7 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1113
# 4   HIToolbox                           0x00007ff813c42173 _ZN15MenuBarInstance19SetFullScreenUIModeEjj + 175
# 5   AppKit                              0x00007ff80d1094b7 -[NSApplication _setPresentationOptions:instance:flags:] + 1145
# 6   AppKit                              0x00007ff80cf5e165 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 582
# 7   CoreFoundation                      0x00007ff809d3d6d6 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 8   CoreFoundation                      0x00007ff809dd6cbc ___CFXRegistrationPost_block_invoke + 86
# 9   CoreFoundation                      0x00007ff809dd6c13 _CFXRegistrationPost + 534
# 10  CoreFoundation                      0x00007ff809d10e31 _CFXNotificationPost + 809
# 11  Foundation                          0x00007ff80aa85f2c -[NSNotificationCenter postNotificationName:object:userInfo:] + 82
# 12  AppKit                              0x00007ff80d109b28 spacesNotificationHandler + 119
# 13  SkyLight                            0x00007ff80e8a774d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 14  SkyLight                            0x00007ff80e8a5cf3 CGSSnarfAndDispatchDatagrams + 1055
# 15  SkyLight                            0x00007ff80ebb4676 SLSGetNextEventRecordInternal + 284
# 16  SkyLight                            0x00007ff80e9d13e8 SLEventCreateNextEvent + 9
# 17  HIToolbox                           0x00007ff813bdc156 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 45
# 18  HIToolbox                           0x00007ff813bdc0fb _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 48
# 19  CoreFoundation                      0x00007ff809d7519c __CFMachPortPerform + 244
# 20  CoreFoundation                      0x00007ff809d48408 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 41
# 21  CoreFoundation                      0x00007ff809d48347 __CFRunLoopDoSource1 + 536
# 22  CoreFoundation                      0x00007ff809d46fc6 __CFRunLoopRun + 2749
# 23  CoreFoundation                      0x00007ff809d45e8f CFRunLoopRunSpecific + 560
# 24  HIToolbox                           0x00007ff813bcf766 RunCurrentEventLoopInMode + 292
# 25  HIToolbox                           0x00007ff813bcf396 ReceiveNextEventCommon + 199
# 26  HIToolbox                           0x00007ff813bcf2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 27  AppKit                              0x00007ff80cdccf33 _DPSNextEvent + 909
# 28  AppKit                              0x00007ff80cdcbdb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 29  cv2.abi3.so                         0x0000000135c251df cvWaitKey + 319
# 30  cv2.abi3.so                         0x0000000135c1eab6 _ZN2cv9waitKeyExEi + 198
# 31  cv2.abi3.so                         0x0000000135c1ebc4 _ZN2cv7waitKeyEi + 36
# 32  cv2.abi3.so                         0x0000000134af91e4 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 33  python3.9                           0x0000000102d7fbb4 cfunction_call + 52
# 34  python3.9                           0x0000000102d23d36 _PyObject_MakeTpCall + 134
# 35  python3.9                           0x0000000102e51bc7 call_function + 311
# 36  python3.9                           0x0000000102e4a988 _PyEval_EvalFrameDefault + 27608
# 37  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 38  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 39  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 40  python3.9                           0x0000000102e51b3e call_function + 174
# 41  python3.9                           0x0000000102e4535c _PyEval_EvalFrameDefault + 5548
# 42  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 43  python3.9                           0x0000000102e3cc99 builtin_exec + 377
# 44  python3.9                           0x0000000102d80565 cfunction_vectorcall_FASTCALL + 85
# 45  python3.9                           0x0000000102e51b3e call_function + 174
# 46  python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 47  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 48  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 49  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 50  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 51  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 52  python3.9                           0x0000000102d32817 method_vectorcall_O + 103
# 53  python3.9                           0x0000000102e51b3e call_function + 174
# 54  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 55  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 56  python3.9                           0x0000000102e51b3e call_function + 174
# 57  python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 58  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 59  python3.9                           0x0000000102e51b3e call_function + 174
# 60  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 61  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 62  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 63  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 64  python3.9                           0x0000000102d24633 PyVectorcall_Call + 163
# 65  python3.9                           0x0000000102e494a7 _PyEval_EvalFrameDefault + 22263
# 66  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 67  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 68  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 69  python3.9                           0x0000000102e51b3e call_function + 174
# 70  python3.9                           0x0000000102e4535c _PyEval_EvalFrameDefault + 5548
# 71  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 72  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 73  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 74  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 75  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 76  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 77  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 78  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 79  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 80  _asyncio.cpython-39-darwin.so       0x000000010bef397a task_step_impl + 442
# 81  _asyncio.cpython-39-darwin.so       0x000000010bef372e task_step + 62
# 82  _asyncio.cpython-39-darwin.so       0x000000010bef35c8 task_wakeup + 104
# 83  _asyncio.cpython-39-darwin.so       0x000000010bef34bd TaskWakeupMethWrapper_call + 109
# 84  python3.9                           0x0000000102d23d36 _PyObject_MakeTpCall + 134
# 85  python3.9                           0x0000000102e6d321 context_run + 81
# 86  python3.9                           0x0000000102d8049c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 87  python3.9                           0x0000000102e494a7 _PyEval_EvalFrameDefault + 22263
# 88  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 89  python3.9                           0x0000000102e51b3e call_function + 174
# 90  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 91  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 92  python3.9                           0x0000000102e51b3e call_function + 174
# 93  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 94  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 95  python3.9                           0x0000000102e51b3e call_function + 174
# 96  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 97  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 98  python3.9                           0x0000000102e51b3e call_function + 174
# 99  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 100 python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 101 python3.9                           0x0000000102e51b3e call_function + 174
# 102 python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 103 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 104 python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 105 python3.9                           0x0000000102d27cde method_vectorcall + 158
# 106 python3.9                           0x0000000102e51b3e call_function + 174
# 107 python3.9                           0x0000000102e4a988 _PyEval_EvalFrameDefault + 27608
# 108 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 109 python3.9                           0x0000000102e3cc99 builtin_exec + 377
# 110 python3.9                           0x0000000102d80565 cfunction_vectorcall_FASTCALL + 85
# 111 python3.9                           0x0000000102e51b3e call_function + 174
# 112 python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 113 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 114 python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 115 python3.9                           0x0000000102e51b3e call_function + 174
# 116 python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 117 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 118 python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 119 python3.9                           0x0000000102ed5ec2 pymain_run_module + 258
# 120 python3.9                           0x0000000102ed5781 pymain_run_python + 241
# 121 python3.9                           0x0000000102ed5645 Py_RunMain + 37
# 122 python3.9                           0x0000000102ed6d10 pymain_main + 64
# 123 python3.9                           0x0000000102cbb238 main + 56
# 124 dyld                                0x00000002033fb310 start + 2432
# 1   HIToolbox                           0x00007ff813bcf0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff813c0b638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff80e8a774d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff80e8a5cf3 CGSSnarfAndDispatchDatagrams + 1055
# 5   SkyLight                            0x00007ff80ebb4676 SLSGetNextEventRecordInternal + 284
# 6   SkyLight                            0x00007ff80e9d13e8 SLEventCreateNextEvent + 9
# 7   HIToolbox                           0x00007ff813bdc156 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 45
# 8   HIToolbox                           0x00007ff813bdc0fb _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 48
# 9   CoreFoundation                      0x00007ff809d7519c __CFMachPortPerform + 244
# 10  CoreFoundation                      0x00007ff809d48408 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 41
# 11  CoreFoundation                      0x00007ff809d48347 __CFRunLoopDoSource1 + 536
# 12  CoreFoundation                      0x00007ff809d46fc6 __CFRunLoopRun + 2749
# 13  CoreFoundation                      0x00007ff809d45e8f CFRunLoopRunSpecific + 560
# 14  HIToolbox                           0x00007ff813bcf766 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x00007ff813bcf396 ReceiveNextEventCommon + 199
# 16  HIToolbox                           0x00007ff813bcf2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 17  AppKit                              0x00007ff80cdccf33 _DPSNextEvent + 909
# 18  AppKit                              0x00007ff80cdcbdb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 19  cv2.abi3.so                         0x0000000135c251df cvWaitKey + 319
# 20  cv2.abi3.so                         0x0000000135c1eab6 _ZN2cv9waitKeyExEi + 198
# 21  cv2.abi3.so                         0x0000000135c1ebc4 _ZN2cv7waitKeyEi + 36
# 22  cv2.abi3.so                         0x0000000134af91e4 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.9                           0x0000000102d7fbb4 cfunction_call + 52
# 24  python3.9                           0x0000000102d23d36 _PyObject_MakeTpCall + 134
# 25  python3.9                           0x0000000102e51bc7 call_function + 311
# 26  python3.9                           0x0000000102e4a988 _PyEval_EvalFrameDefault + 27608
# 27  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 28  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 29  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 30  python3.9                           0x0000000102e51b3e call_function + 174
# 31  python3.9                           0x0000000102e4535c _PyEval_EvalFrameDefault + 5548
# 32  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 33  python3.9                           0x0000000102e3cc99 builtin_exec + 377
# 34  python3.9                           0x0000000102d80565 cfunction_vectorcall_FASTCALL + 85
# 35  python3.9                           0x0000000102e51b3e call_function + 174
# 36  python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 37  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 38  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 39  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 40  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 41  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 42  python3.9                           0x0000000102d32817 method_vectorcall_O + 103
# 43  python3.9                           0x0000000102e51b3e call_function + 174
# 44  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 45  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 46  python3.9                           0x0000000102e51b3e call_function + 174
# 47  python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 48  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 49  python3.9                           0x0000000102e51b3e call_function + 174
# 50  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 51  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 52  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 53  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 54  python3.9                           0x0000000102d24633 PyVectorcall_Call + 163
# 55  python3.9                           0x0000000102e494a7 _PyEval_EvalFrameDefault + 22263
# 56  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 57  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 58  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 59  python3.9                           0x0000000102e51b3e call_function + 174
# 60  python3.9                           0x0000000102e4535c _PyEval_EvalFrameDefault + 5548
# 61  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 62  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 63  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 64  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 65  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 66  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 67  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 68  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 69  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 70  _asyncio.cpython-39-darwin.so       0x000000010bef397a task_step_impl + 442
# 71  _asyncio.cpython-39-darwin.so       0x000000010bef372e task_step + 62
# 72  _asyncio.cpython-39-darwin.so       0x000000010bef35c8 task_wakeup + 104
# 73  _asyncio.cpython-39-darwin.so       0x000000010bef34bd TaskWakeupMethWrapper_call + 109
# 74  python3.9                           0x0000000102d23d36 _PyObject_MakeTpCall + 134
# 75  python3.9                           0x0000000102e6d321 context_run + 81
# 76  python3.9                           0x0000000102d8049c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 77  python3.9                           0x0000000102e494a7 _PyEval_EvalFrameDefault + 22263
# 78  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 79  python3.9                           0x0000000102e51b3e call_function + 174
# 80  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 81  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 82  python3.9                           0x0000000102e51b3e call_function + 174
# 83  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 84  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 85  python3.9                           0x0000000102e51b3e call_function + 174
# 86  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 87  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 88  python3.9                           0x0000000102e51b3e call_function + 174
# 89  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 90  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 91  python3.9                           0x0000000102e51b3e call_function + 174
# 92  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 93  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 94  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 95  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 96  python3.9                           0x0000000102e51b3e call_function + 174
# 97  python3.9                           0x0000000102e4a988 _PyEval_EvalFrameDefault + 27608
# 98  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 99  python3.9                           0x0000000102e3cc99 builtin_exec + 377
# 100 python3.9                           0x0000000102d80565 cfunction_vectorcall_FASTCALL + 85
# 101 python3.9                           0x0000000102e51b3e call_function + 174
# 102 python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 103 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 104 python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 105 python3.9                           0x0000000102e51b3e call_function + 174
# 106 python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 107 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 108 python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 109 python3.9                           0x0000000102ed5ec2 pymain_run_module + 258
# 110 python3.9                           0x0000000102ed5781 pymain_run_python + 241
# 111 python3.9                           0x0000000102ed5645 Py_RunMain + 37
# 112 python3.9                           0x0000000102ed6d10 pymain_main + 64
# 113 python3.9                           0x0000000102cbb238 main + 56
# 114 dyld                                0x00000002033fb310 start + 2432
# 1   HIToolbox                           0x00007ff813c42726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff813c0b638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff80e8a774d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff80e8a5cf3 CGSSnarfAndDispatchDatagrams + 1055
# 5   SkyLight                            0x00007ff80ebb4676 SLSGetNextEventRecordInternal + 284
# 6   SkyLight                            0x00007ff80e9d13e8 SLEventCreateNextEvent + 9
# 7   HIToolbox                           0x00007ff813bdc156 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 45
# 8   HIToolbox                           0x00007ff813bdc0fb _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 48
# 9   CoreFoundation                      0x00007ff809d7519c __CFMachPortPerform + 244
# 10  CoreFoundation                      0x00007ff809d48408 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 41
# 11  CoreFoundation                      0x00007ff809d48347 __CFRunLoopDoSource1 + 536
# 12  CoreFoundation                      0x00007ff809d46fc6 __CFRunLoopRun + 2749
# 13  CoreFoundation                      0x00007ff809d45e8f CFRunLoopRunSpecific + 560
# 14  HIToolbox                           0x00007ff813bcf766 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x00007ff813bcf396 ReceiveNextEventCommon + 199
# 16  HIToolbox                           0x00007ff813bcf2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 17  AppKit                              0x00007ff80cdccf33 _DPSNextEvent + 909
# 18  AppKit                              0x00007ff80cdcbdb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 19  cv2.abi3.so                         0x0000000135c251df cvWaitKey + 319
# 20  cv2.abi3.so                         0x0000000135c1eab6 _ZN2cv9waitKeyExEi + 198
# 21  cv2.abi3.so                         0x0000000135c1ebc4 _ZN2cv7waitKeyEi + 36
# 22  cv2.abi3.so                         0x0000000134af91e4 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 23  python3.9                           0x0000000102d7fbb4 cfunction_call + 52
# 24  python3.9                           0x0000000102d23d36 _PyObject_MakeTpCall + 134
# 25  python3.9                           0x0000000102e51bc7 call_function + 311
# 26  python3.9                           0x0000000102e4a988 _PyEval_EvalFrameDefault + 27608
# 27  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 28  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 29  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 30  python3.9                           0x0000000102e51b3e call_function + 174
# 31  python3.9                           0x0000000102e4535c _PyEval_EvalFrameDefault + 5548
# 32  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 33  python3.9                           0x0000000102e3cc99 builtin_exec + 377
# 34  python3.9                           0x0000000102d80565 cfunction_vectorcall_FASTCALL + 85
# 35  python3.9                           0x0000000102e51b3e call_function + 174
# 36  python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 37  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 38  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 39  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 40  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 41  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 42  python3.9                           0x0000000102d32817 method_vectorcall_O + 103
# 43  python3.9                           0x0000000102e51b3e call_function + 174
# 44  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 45  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 46  python3.9                           0x0000000102e51b3e call_function + 174
# 47  python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 48  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 49  python3.9                           0x0000000102e51b3e call_function + 174
# 50  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 51  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 52  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 53  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 54  python3.9                           0x0000000102d24633 PyVectorcall_Call + 163
# 55  python3.9                           0x0000000102e494a7 _PyEval_EvalFrameDefault + 22263
# 56  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 57  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 58  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 59  python3.9                           0x0000000102e51b3e call_function + 174
# 60  python3.9                           0x0000000102e4535c _PyEval_EvalFrameDefault + 5548
# 61  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 62  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 63  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 64  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 65  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 66  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 67  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 68  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 69  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 70  _asyncio.cpython-39-darwin.so       0x000000010bef397a task_step_impl + 442
# 71  _asyncio.cpython-39-darwin.so       0x000000010bef372e task_step + 62
# 72  _asyncio.cpython-39-darwin.so       0x000000010bef35c8 task_wakeup + 104
# 73  _asyncio.cpython-39-darwin.so       0x000000010bef34bd TaskWakeupMethWrapper_call + 109
# 74  python3.9                           0x0000000102d23d36 _PyObject_MakeTpCall + 134
# 75  python3.9                           0x0000000102e6d321 context_run + 81
# 76  python3.9                           0x0000000102d8049c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 77  python3.9                           0x0000000102e494a7 _PyEval_EvalFrameDefault + 22263
# 78  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 79  python3.9                           0x0000000102e51b3e call_function + 174
# 80  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 81  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 82  python3.9                           0x0000000102e51b3e call_function + 174
# 83  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 84  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 85  python3.9                           0x0000000102e51b3e call_function + 174
# 86  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 87  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 88  python3.9                           0x0000000102e51b3e call_function + 174
# 89  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 90  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 91  python3.9                           0x0000000102e51b3e call_function + 174
# 92  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 93  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 94  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 95  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 96  python3.9                           0x0000000102e51b3e call_function + 174
# 97  python3.9                           0x0000000102e4a988 _PyEval_EvalFrameDefault + 27608
# 98  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 99  python3.9                           0x0000000102e3cc99 builtin_exec + 377
# 100 python3.9                           0x0000000102d80565 cfunction_vectorcall_FASTCALL + 85
# 101 python3.9                           0x0000000102e51b3e call_function + 174
# 102 python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 103 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 104 python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 105 python3.9                           0x0000000102e51b3e call_function + 174
# 106 python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 107 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 108 python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 109 python3.9                           0x0000000102ed5ec2 pymain_run_module + 258
# 110 python3.9                           0x0000000102ed5781 pymain_run_python + 241
# 111 python3.9                           0x0000000102ed5645 Py_RunMain + 37
# 112 python3.9                           0x0000000102ed6d10 pymain_main + 64
# 113 python3.9                           0x0000000102cbb238 main + 56
# 114 dyld                                0x00000002033fb310 start + 2432
# 1   HIToolbox                           0x00007ff813bcf0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff813bb1ce3 _ZN15MenuBarInstance21UpdateAggregateUIModeE21MenuBarAnimationStylehhh + 1125
# 3   HIToolbox                           0x00007ff813bb17a4 _ZN15MenuBarInstance16ForEachMenuBarDoEU13block_pointerFvPS_E + 46
# 4   HIToolbox                           0x00007ff813bb1762 SetSystemUIMode + 209
# 5   AppKit                              0x00007ff80d1094c3 -[NSApplication _setPresentationOptions:instance:flags:] + 1157
# 6   AppKit                              0x00007ff80cf5e185 -[NSApplication _updateFullScreenPresentationOptionsForInstance:] + 614
# 7   CoreFoundation                      0x00007ff809d3d6d6 __CFNOTIFICATIONCENTER_IS_CALLING_OUT_TO_AN_OBSERVER__ + 137
# 8   CoreFoundation                      0x00007ff809dd6cbc ___CFXRegistrationPost_block_invoke + 86
# 9   CoreFoundation                      0x00007ff809dd6c13 _CFXRegistrationPost + 534
# 10  CoreFoundation                      0x00007ff809d10e31 _CFXNotificationPost + 809
# 11  Foundation                          0x00007ff80aa85f2c -[NSNotificationCenter postNotificationName:object:userInfo:] + 82
# 12  AppKit                              0x00007ff80d109b28 spacesNotificationHandler + 119
# 13  SkyLight                            0x00007ff80e8a774d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 14  SkyLight                            0x00007ff80e8a5cf3 CGSSnarfAndDispatchDatagrams + 1055
# 15  SkyLight                            0x00007ff80ebb4676 SLSGetNextEventRecordInternal + 284
# 16  SkyLight                            0x00007ff80e9d13e8 SLEventCreateNextEvent + 9
# 17  HIToolbox                           0x00007ff813bdc156 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 45
# 18  HIToolbox                           0x00007ff813bdc0fb _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 48
# 19  CoreFoundation                      0x00007ff809d7519c __CFMachPortPerform + 244
# 20  CoreFoundation                      0x00007ff809d48408 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 41
# 21  CoreFoundation                      0x00007ff809d48347 __CFRunLoopDoSource1 + 536
# 22  CoreFoundation                      0x00007ff809d46fc6 __CFRunLoopRun + 2749
# 23  CoreFoundation                      0x00007ff809d45e8f CFRunLoopRunSpecific + 560
# 24  HIToolbox                           0x00007ff813bcf766 RunCurrentEventLoopInMode + 292
# 25  HIToolbox                           0x00007ff813bcf396 ReceiveNextEventCommon + 199
# 26  HIToolbox                           0x00007ff813bcf2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 27  AppKit                              0x00007ff80cdccf33 _DPSNextEvent + 909
# 28  AppKit                              0x00007ff80cdcbdb4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 29  cv2.abi3.so                         0x0000000135c251df cvWaitKey + 319
# 30  cv2.abi3.so                         0x0000000135c1eab6 _ZN2cv9waitKeyExEi + 198
# 31  cv2.abi3.so                         0x0000000135c1ebc4 _ZN2cv7waitKeyEi + 36
# 32  cv2.abi3.so                         0x0000000134af91e4 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 33  python3.9                           0x0000000102d7fbb4 cfunction_call + 52
# 34  python3.9                           0x0000000102d23d36 _PyObject_MakeTpCall + 134
# 35  python3.9                           0x0000000102e51bc7 call_function + 311
# 36  python3.9                           0x0000000102e4a988 _PyEval_EvalFrameDefault + 27608
# 37  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 38  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 39  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 40  python3.9                           0x0000000102e51b3e call_function + 174
# 41  python3.9                           0x0000000102e4535c _PyEval_EvalFrameDefault + 5548
# 42  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 43  python3.9                           0x0000000102e3cc99 builtin_exec + 377
# 44  python3.9                           0x0000000102d80565 cfunction_vectorcall_FASTCALL + 85
# 45  python3.9                           0x0000000102e51b3e call_function + 174
# 46  python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 47  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 48  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 49  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 50  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 51  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 52  python3.9                           0x0000000102d32817 method_vectorcall_O + 103
# 53  python3.9                           0x0000000102e51b3e call_function + 174
# 54  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 55  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 56  python3.9                           0x0000000102e51b3e call_function + 174
# 57  python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 58  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 59  python3.9                           0x0000000102e51b3e call_function + 174
# 60  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 61  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 62  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 63  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 64  python3.9                           0x0000000102d24633 PyVectorcall_Call + 163
# 65  python3.9                           0x0000000102e494a7 _PyEval_EvalFrameDefault + 22263
# 66  python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 67  python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 68  python3.9                           0x0000000102d27cde method_vectorcall + 158
# 69  python3.9                           0x0000000102e51b3e call_function + 174
# 70  python3.9                           0x0000000102e4535c _PyEval_EvalFrameDefault + 5548
# 71  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 72  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 73  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 74  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 75  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 76  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 77  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 78  python3.9                           0x0000000102e4bcf3 _PyEval_EvalFrameDefault + 32579
# 79  python3.9                           0x0000000102d3db7f gen_send_ex + 175
# 80  _asyncio.cpython-39-darwin.so       0x000000010bef397a task_step_impl + 442
# 81  _asyncio.cpython-39-darwin.so       0x000000010bef372e task_step + 62
# 82  _asyncio.cpython-39-darwin.so       0x000000010bef35c8 task_wakeup + 104
# 83  _asyncio.cpython-39-darwin.so       0x000000010bef34bd TaskWakeupMethWrapper_call + 109
# 84  python3.9                           0x0000000102d23d36 _PyObject_MakeTpCall + 134
# 85  python3.9                           0x0000000102e6d321 context_run + 81
# 86  python3.9                           0x0000000102d8049c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 87  python3.9                           0x0000000102e494a7 _PyEval_EvalFrameDefault + 22263
# 88  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 89  python3.9                           0x0000000102e51b3e call_function + 174
# 90  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 91  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 92  python3.9                           0x0000000102e51b3e call_function + 174
# 93  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 94  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 95  python3.9                           0x0000000102e51b3e call_function + 174
# 96  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 97  python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 98  python3.9                           0x0000000102e51b3e call_function + 174
# 99  python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 100 python3.9                           0x0000000102d24a7b function_code_fastcall + 139
# 101 python3.9                           0x0000000102e51b3e call_function + 174
# 102 python3.9                           0x0000000102e4576a _PyEval_EvalFrameDefault + 6586
# 103 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 104 python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 105 python3.9                           0x0000000102d27cde method_vectorcall + 158
# 106 python3.9                           0x0000000102e51b3e call_function + 174
# 107 python3.9                           0x0000000102e4a988 _PyEval_EvalFrameDefault + 27608
# 108 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 109 python3.9                           0x0000000102e3cc99 builtin_exec + 377
# 110 python3.9                           0x0000000102d80565 cfunction_vectorcall_FASTCALL + 85
# 111 python3.9                           0x0000000102e51b3e call_function + 174
# 112 python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 113 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 114 python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 115 python3.9                           0x0000000102e51b3e call_function + 174
# 116 python3.9                           0x0000000102e49c1d _PyEval_EvalFrameDefault + 24173
# 117 python3.9                           0x0000000102e426e9 _PyEval_EvalCode + 489
# 118 python3.9                           0x0000000102d249bc _PyFunction_Vectorcall + 236
# 119 python3.9                           0x0000000102ed5ec2 pymain_run_module + 258
# 120 python3.9                           0x0000000102ed5781 pymain_run_python + 241
# 121 python3.9                           0x0000000102ed5645 Py_RunMain + 37
# 122 python3.9                           0x0000000102ed6d10 pymain_main + 64
# 123 python3.9                           0x0000000102cbb238 main + 56
# 124 dyld                                0x00000002033fb310 start + 2432
